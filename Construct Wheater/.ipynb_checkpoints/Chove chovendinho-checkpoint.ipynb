# %% [markdown]
# # Constructo Wheater

# %% [markdown]
# ### A ideia é fazer tirar uma média por mês de dias que chovem suficientemente para atraphalhar o andamento da obra, para então prever isso no cronograma.

# %% [markdown]
# ### Dados do INMET estação metereológica de Sorocaba-SP - Série Histórica, diária de 01/01/2000 - 17/11/2018

# %% [markdown]
# Acho que talvez seja interessante criar as classes: Chovendinho (atrapalha alguns serviços), chovendo (atrapalha alvenaria), chovendão ( obra alagada), Calamidade de chuva, OMG

# %%
#imports
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('data/raw 2 c.csv', sep=';')

# %%
df.head()
# Out:
#    Estacao        Data  Hora  Precipitacao  TempMaxima  TempMinima  Insolacao  \
# 0    83851  01/02/1998     0           NaN        33.5         NaN        6.1
# 1    83851  01/02/1998  1200           0.0         NaN        23.5        NaN
# 2    83851  02/02/1998     0           NaN        34.1         NaN        7.6
# 3    83851  02/02/1998  1200           0.7         NaN        22.0        NaN
# 4    83851  03/02/1998     0           NaN        33.5         NaN        6.2
#
#    Evaporacao Piche  Temp Comp Media  Umidade Relativa Media  \
# 0               3.0            26.84                   84.50
# 1               NaN              NaN                     NaN
# 2               3.9            27.10                   73.25
# 3               NaN              NaN                     NaN
# 4               3.4            25.66                   70.75
#
#   Velocidade do Vento Media
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
df.describe()
# Out:
#        Estacao          Hora  Precipitacao   TempMaxima   TempMinima  \
# count  13097.0  13097.000000   6559.000000  6516.000000  6499.000000
# mean   83851.0    601.603421      3.686416    27.778622    16.687475
# std        0.0    600.020765     10.510229     4.017201     3.517677
# min    83851.0      0.000000      0.000000    10.700000     3.200000
# 25%    83851.0      0.000000      0.000000    25.200000    14.200000
# 50%    83851.0   1200.000000      0.000000    28.100000    17.000000
# 75%    83851.0   1200.000000      1.000000    30.800000    19.700000
# max    83851.0   1200.000000    164.400000    37.800000    25.100000
#
#          Insolacao  Evaporacao Piche  Temp Comp Media  Umidade Relativa Media
# count  6516.000000       6440.000000      6504.000000             6503.000000
# mean      6.053161          3.507733        21.204299               74.689374
# std       3.380624          1.624978         3.359422                9.683246
# min       0.000000          0.000000         9.100000               38.750000
# 25%       3.275000          2.400000        18.840000               69.000000
# 50%       7.000000          3.400000        21.490000               74.750000
# 75%       8.800000          4.400000        23.780000               81.000000
# max      12.400000         13.900000        29.740000               99.000000

# %%
df.tail()
# Out:
#        Estacao        Data  Hora  Precipitacao  TempMaxima  TempMinima  \
# 13092    83851  22/12/2017  1200          10.6         NaN        20.1
# 13093    83851  25/12/2017     0           NaN        29.5         NaN
# 13094    83851  25/12/2017  1200           0.0         NaN        20.1
# 13095    83851  26/12/2017     0           NaN        31.1         NaN
# 13096    83851  26/12/2017  1200          23.6         NaN        19.9
#
#        Insolacao  Evaporacao Piche  Temp Comp Media  Umidade Relativa Media  \
# 13092        NaN               NaN              NaN                     NaN
# 13093        0.6               NaN            23.04                    94.0
# 13094        NaN               NaN              NaN                     NaN
# 13095        4.7               7.6            25.20                    77.0
# 13096        NaN               NaN              NaN                     NaN
#
#       Velocidade do Vento Media
# 13092                       NaN
# 13093                         1
# 13094                       NaN
# 13095                       0.5
# 13096                       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13097 entries, 0 to 13096
# Data columns (total 11 columns):
# Estacao                      13097 non-null int64
# Data                         13097 non-null object
# Hora                         13097 non-null int64
# Precipitacao                 6559 non-null float64
# TempMaxima                   6516 non-null float64
# TempMinima                   6499 non-null float64
# Insolacao                    6516 non-null float64
# Evaporacao Piche             6440 non-null float64
# Temp Comp Media              6504 non-null float64
# Umidade Relativa Media       6503 non-null float64
# Velocidade do Vento Media    5830 non-null object
# dtypes: float64(7), int64(2), object(2)
# memory usage: 1.1+ MB

# %%
df['DataConvertida'] = pd.to_datetime(df['Data'], format='%d/%m/%Y')

# %%
df.head()
# Out:
#    Estacao        Data  Hora  Precipitacao  TempMaxima  TempMinima  Insolacao  \
# 0    83851  01/02/1998     0           NaN        33.5         NaN        6.1
# 1    83851  01/02/1998  1200           0.0         NaN        23.5        NaN
# 2    83851  02/02/1998     0           NaN        34.1         NaN        7.6
# 3    83851  02/02/1998  1200           0.7         NaN        22.0        NaN
# 4    83851  03/02/1998     0           NaN        33.5         NaN        6.2
#
#    Evaporacao Piche  Temp Comp Media  Umidade Relativa Media  \
# 0               3.0            26.84                   84.50
# 1               NaN              NaN                     NaN
# 2               3.9            27.10                   73.25
# 3               NaN              NaN                     NaN
# 4               3.4            25.66                   70.75
#
#   Velocidade do Vento Media DataConvertida
# 0                       NaN     1998-02-01
# 1                       NaN     1998-02-01
# 2                       NaN     1998-02-02
# 3                       NaN     1998-02-02
# 4                       NaN     1998-02-03

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13097 entries, 0 to 13096
# Data columns (total 12 columns):
# Estacao                      13097 non-null int64
# Data                         13097 non-null object
# Hora                         13097 non-null int64
# Precipitacao                 6559 non-null float64
# TempMaxima                   6516 non-null float64
# TempMinima                   6499 non-null float64
# Insolacao                    6516 non-null float64
# Evaporacao Piche             6440 non-null float64
# Temp Comp Media              6504 non-null float64
# Umidade Relativa Media       6503 non-null float64
# Velocidade do Vento Media    5830 non-null object
# DataConvertida               13097 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int64(2), object(2)
# memory usage: 1.2+ MB

# %%
#--Corrigindo TempMinima e Precipitacao
#Splita rows por hora em 2 dataframes
dfTemp12 = df[df.Hora == 1200]
dfTemp00 = df[df.Hora == 0]

#Imprime dimensoes de ambos subsets e do dataset completo
print("dfTemp00.shape: "+str(dfTemp00.shape)+
      "\ndfTemp12.shape: "+str(dfTemp12.shape)+
      "\ndf.shape: "+str(df.shape)
     )
# Out:
# dfTemp00.shape: (6531, 12)
# dfTemp12.shape: (6566, 12)
# df.shape: (13097, 12)

# %%
#Define chaves para join
dfTemp00['chave'] = dfTemp00["Estacao"].map(str) + dfTemp00["Data"].map(str)
dfTemp12['chave'] = dfTemp12["Estacao"].map(str) + dfTemp12["Data"].map(str)

#Evidencia variaveis TemMinima e Precipitacao deletando demais colunas
dfTemp12.drop(dfTemp12.columns[[0,1,2,4,6,7,8,9,10]], axis=1, inplace=True)
dfTemp12.head()
# Out:
# D:\Arquivosdeprogramas\anaconda\envs\tera-jul2018\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\Arquivosdeprogramas\anaconda\envs\tera-jul2018\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Arquivosdeprogramas\anaconda\envs\tera-jul2018\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Precipitacao  TempMinima DataConvertida            chave
# 1           0.0        23.5     1998-02-01  8385101/02/1998
# 3           0.7        22.0     1998-02-02  8385102/02/1998
# 5           0.0        22.0     1998-02-03  8385103/02/1998
# 7           0.0        20.5     1998-02-04  8385104/02/1998
# 9           0.0        21.0     1998-02-05  8385105/02/1998

# %%
#Faz o join
df_j = dfTemp00.set_index('chave').join(dfTemp12.set_index('chave'), lsuffix='_00', rsuffix='_12')
# dfEstCamposJoined["TempMinima_00"].mean()
df_j["TempMinima_12"].mean()
# Out:
# 16.687474996153252

# %%
df_j.head()
# Out:
#                  Estacao        Data  Hora  Precipitacao_00  TempMaxima  \
# chave
# 8385101/02/1998    83851  01/02/1998     0              NaN        33.5
# 8385102/02/1998    83851  02/02/1998     0              NaN        34.1
# 8385103/02/1998    83851  03/02/1998     0              NaN        33.5
# 8385104/02/1998    83851  04/02/1998     0              NaN        34.1
# 8385105/02/1998    83851  05/02/1998     0              NaN        34.5
#
#                  TempMinima_00  Insolacao  Evaporacao Piche  Temp Comp Media  \
# chave
# 8385101/02/1998            NaN        6.1               3.0            26.84
# 8385102/02/1998            NaN        7.6               3.9            27.10
# 8385103/02/1998            NaN        6.2               3.4            25.66
# 8385104/02/1998            NaN        6.1               3.9            26.16
# 8385105/02/1998            NaN        8.6               3.7            25.62
#
#                  Umidade Relativa Media Velocidade do Vento Media  \
# chave
# 8385101/02/1998                   84.50                       NaN
# 8385102/02/1998                   73.25                       NaN
# 8385103/02/1998                   70.75                       NaN
# 8385104/02/1998                   70.25                       NaN
# 8385105/02/1998                   76.75                       NaN
#
#                 DataConvertida_00  Precipitacao_12  TempMinima_12  \
# chave
# 8385101/02/1998        1998-02-01              0.0           23.5
# 8385102/02/1998        1998-02-02              0.7           22.0
# 8385103/02/1998        1998-02-03              0.0           22.0
# 8385104/02/1998        1998-02-04              0.0           20.5
# 8385105/02/1998        1998-02-05              0.0           21.0
#
#                 DataConvertida_12
# chave
# 8385101/02/1998        1998-02-01
# 8385102/02/1998        1998-02-02
# 8385103/02/1998        1998-02-03
# 8385104/02/1998        1998-02-04
# 8385105/02/1998        1998-02-05

# %%
#Cria novas variaveis TempMinima e Precipitacao
df_j["TempMinima"] = df_j["TempMinima_12"]
df_j["Precipitacao"] = df_j["Precipitacao_12"]

#Remove colunas temporarias para o join
df_j.drop('TempMinima_00', axis=1, inplace=True)
df_j.drop('TempMinima_12', axis=1, inplace=True)
df_j.drop('Precipitacao_00', axis=1, inplace=True)
df_j.drop('Precipitacao_12', axis=1, inplace=True)

#Reseta o index
df_j = df_j.reset_index(drop=True)

#Renomeia dataframe corrigido
df_j = df_j
df_j.head()
# dfEstCamposCorrigido.tail()
# Out:
#    Estacao        Data  Hora  TempMaxima  Insolacao  Evaporacao Piche  \
# 0    83851  01/02/1998     0        33.5        6.1               3.0
# 1    83851  02/02/1998     0        34.1        7.6               3.9
# 2    83851  03/02/1998     0        33.5        6.2               3.4
# 3    83851  04/02/1998     0        34.1        6.1               3.9
# 4    83851  05/02/1998     0        34.5        8.6               3.7
#
#    Temp Comp Media  Umidade Relativa Media Velocidade do Vento Media  \
# 0            26.84                   84.50                       NaN
# 1            27.10                   73.25                       NaN
# 2            25.66                   70.75                       NaN
# 3            26.16                   70.25                       NaN
# 4            25.62                   76.75                       NaN
#
#   DataConvertida_00 DataConvertida_12  TempMinima  Precipitacao
# 0        1998-02-01        1998-02-01        23.5           0.0
# 1        1998-02-02        1998-02-02        22.0           0.7
# 2        1998-02-03        1998-02-03        22.0           0.0
# 3        1998-02-04        1998-02-04        20.5           0.0
# 4        1998-02-05        1998-02-05        21.0           0.0

# %%
df_j.isnull().sum()
# Out:
# Estacao                        0
# Data                           0
# Hora                           0
# TempMaxima                    15
# Insolacao                     15
# Evaporacao Piche              91
# Temp Comp Media               27
# Umidade Relativa Media        28
# Velocidade do Vento Media    701
# DataConvertida_00              0
# DataConvertida_12              1
# TempMinima                    32
# Precipitacao                   8
# dtype: int64

# %%
df_j.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6531 entries, 0 to 6530
# Data columns (total 13 columns):
# Estacao                      6531 non-null int64
# Data                         6531 non-null object
# Hora                         6531 non-null int64
# TempMaxima                   6516 non-null float64
# Insolacao                    6516 non-null float64
# Evaporacao Piche             6440 non-null float64
# Temp Comp Media              6504 non-null float64
# Umidade Relativa Media       6503 non-null float64
# Velocidade do Vento Media    5830 non-null object
# DataConvertida_00            6531 non-null datetime64[ns]
# DataConvertida_12            6530 non-null datetime64[ns]
# TempMinima                   6499 non-null float64
# Precipitacao                 6523 non-null float64
# dtypes: datetime64[ns](2), float64(7), int64(2), object(2)
# memory usage: 663.4+ KB

# %%
df_j.isnull().sum()/len(df_j)
# Out:
# Estacao                      0.000000
# Data                         0.000000
# Hora                         0.000000
# TempMaxima                   0.002297
# Insolacao                    0.002297
# Evaporacao Piche             0.013934
# Temp Comp Media              0.004134
# Umidade Relativa Media       0.004287
# Velocidade do Vento Media    0.107334
# DataConvertida_00            0.000000
# DataConvertida_12            0.000153
# TempMinima                   0.004900
# Precipitacao                 0.001225
# dtype: float64

# %%
df_j.median()
# Out:
# Estacao                   83851.00
# Hora                          0.00
# TempMaxima                   28.10
# Insolacao                     7.00
# Evaporacao Piche              3.40
# Temp Comp Media              21.49
# Umidade Relativa Media       74.75
# TempMinima                   17.00
# Precipitacao                  0.00
# dtype: float64

# %%
df_j['TempMaxima']=df_j['TempMaxima'].fillna(value=28.10)
df_j['Insolacao']=df_j['Insolacao'].fillna(value=7.0)
df_j['Evaporacao Piche']=df_j['Evaporacao Piche'].fillna(value=3.4)
df_j['Umidade Relativa Media']=df_j['Umidade Relativa Media'].fillna(value=74.75)
df_j['TempMinima']=df_j['TempMinima'].fillna(value=17.00)
df_j['Precipitacao']=df_j['Precipitacao'].fillna(value=0.00)
df_j['Temp Comp Media']=df_j['Temp Comp Media'].fillna(value=21.49)

# %%
df_j.isnull().sum()/len(df_j)
# Out:
# Estacao                      0.000000
# Data                         0.000000
# Hora                         0.000000
# TempMaxima                   0.000000
# Insolacao                    0.000000
# Evaporacao Piche             0.000000
# Temp Comp Media              0.000000
# Umidade Relativa Media       0.000000
# Velocidade do Vento Media    0.107334
# DataConvertida_00            0.000000
# DataConvertida_12            0.000153
# TempMinima                   0.000000
# Precipitacao                 0.000000
# dtype: float64

# %%
df_j['mes'] = pd.DatetimeIndex(df_j['DataConvertida_00']).month

# %%
df_j.head()
# Out:
#    Estacao        Data  Hora  TempMaxima  Insolacao  Evaporacao Piche  \
# 0    83851  01/02/1998     0        33.5        6.1               3.0
# 1    83851  02/02/1998     0        34.1        7.6               3.9
# 2    83851  03/02/1998     0        33.5        6.2               3.4
# 3    83851  04/02/1998     0        34.1        6.1               3.9
# 4    83851  05/02/1998     0        34.5        8.6               3.7
#
#    Temp Comp Media  Umidade Relativa Media Velocidade do Vento Media  \
# 0            26.84                   84.50                       NaN
# 1            27.10                   73.25                       NaN
# 2            25.66                   70.75                       NaN
# 3            26.16                   70.25                       NaN
# 4            25.62                   76.75                       NaN
#
#   DataConvertida_00 DataConvertida_12  TempMinima  Precipitacao  mes
# 0        1998-02-01        1998-02-01        23.5           0.0    2
# 1        1998-02-02        1998-02-02        22.0           0.7    2
# 2        1998-02-03        1998-02-03        22.0           0.0    2
# 3        1998-02-04        1998-02-04        20.5           0.0    2
# 4        1998-02-05        1998-02-05        21.0           0.0    2

# %%
df_j['mes'][:200]
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
# 5      2
# 6      2
# 7      2
# 8      2
# 9      2
# 10     2
# 11     2
# 12     2
# 13     2
# 14     2
# 15     2
# 16     2
# 17     2
# 18     2
# 19     2
# 20     2
# 21     2
# 22     2
# 23     2
# 24     2
# 25     2
# 26     2
# 27     2
# 28     3
# 29     3
#       ..
# 170    7
# 171    7
# 172    7
# 173    7
# 174    7
# 175    7
# 176    7
# 177    7
# 178    7
# 179    7
# 180    7
# 181    8
# 182    8
# 183    8
# 184    8
# 185    8
# 186    8
# 187    8
# 188    8
# 189    8
# 190    8
# 191    8
# 192    8
# 193    8
# 194    8
# 195    8
# 196    8
# 197    8
# 198    8
# 199    8
# Name: mes, Length: 200, dtype: int64

# %%
df_j['Precipitacao'][df_j['mes']==4].median()
# Out:
# 0.0

# %%
df_j['Precipitacao'][1]
# Out:
# 0.69999999999999996

# %%
#Sem chuva 0.0 À 3.00 mm
# Chovendinho 3.00 mm à 5.00 mm
# Chovendo 5.00 à 10 mm
# Chuvão 10 à 20 mm
# Catastrofe 20 <
cl_chuva = []
for i in range (len(df_j)):
    if df_j['Precipitacao'][i] <3:
        chuva = 'Sem chuva'
    elif df_j['Precipitacao'][i] <5:
        chuva = 'chovendinho'
    elif df_j['Precipitacao'][i] <10:
        chuva = 'chovendo'
    elif df_j['Precipitacao'][i] <20:
        chuva = 'Chuvao'
    else:
        chuva = 'Catastrofe'
    cl_chuva.append(chuva)

# %%
#Sem chuva 0.0 À 3.00 mm
# Chovendinho 3.00 mm à 5.00 mm
# Chovendo 5.00 à 10 mm
# Chuvão 10 à 20 mm
# Catastrofe 20 <
cl_chuva2 = []
for i in range (len(df_j)):
    if df_j['Precipitacao'][i] <3:
        chuva2 = 0
    elif df_j['Precipitacao'][i] <5:
        chuva2 = 1
    elif df_j['Precipitacao'][i] <10:
        chuva2 = 2
    elif df_j['Precipitacao'][i] <20:
        chuva2 = 3
    else:
        chuva2 = 4
    cl_chuva2.append(chuva2)

# %%
df_j['CL']=cl_chuva

# %%
df_j['CL 2']=cl_chuva2

# %%
df_j[:8]
# Out:
#    Estacao        Data  Hora  TempMaxima  Insolacao  Evaporacao Piche  \
# 0    83851  01/02/1998     0        33.5        6.1               3.0
# 1    83851  02/02/1998     0        34.1        7.6               3.9
# 2    83851  03/02/1998     0        33.5        6.2               3.4
# 3    83851  04/02/1998     0        34.1        6.1               3.9
# 4    83851  05/02/1998     0        34.5        8.6               3.7
# 5    83851  06/02/1998     0        32.1        3.5               2.7
# 6    83851  07/02/1998     0        33.3        5.7               3.8
# 7    83851  08/02/1998     0        32.8        0.3               2.6
#
#    Temp Comp Media  Umidade Relativa Media Velocidade do Vento Media  \
# 0            26.84                   84.50                       NaN
# 1            27.10                   73.25                       NaN
# 2            25.66                   70.75                       NaN
# 3            26.16                   70.25                       NaN
# 4            25.62                   76.75                       NaN
# 5            25.72                   79.50                       NaN
# 6            26.60                   75.75                       NaN
# 7            26.20                   81.75                       NaN
#
#   DataConvertida_00 DataConvertida_12  TempMinima  Precipitacao  mes  \
# 0        1998-02-01        1998-02-01        23.5           0.0    2
# 1        1998-02-02        1998-02-02        22.0           0.7    2
# 2        1998-02-03        1998-02-03        22.0           0.0    2
# 3        1998-02-04        1998-02-04        20.5           0.0    2
# 4        1998-02-05        1998-02-05        21.0           0.0    2
# 5        1998-02-06        1998-02-06        21.5           6.8    2
# 6        1998-02-07        1998-02-07        21.5           0.0    2
# 7        1998-02-08        1998-02-08        23.0           0.0    2
#
#           CL  CL 2
# 0  Sem chuva     0
# 1  Sem chuva     0
# 2  Sem chuva     0
# 3  Sem chuva     0
# 4  Sem chuva     0
# 5   chovendo     2
# 6  Sem chuva     0
# 7  Sem chuva     0

# %%
df_j['CL 2'].hist(bins=20, figsize= (10,10))

# %%
df_j[df_j['mes']==9]
# Out:
#       Estacao        Data  Hora  TempMaxima  Insolacao  Evaporacao Piche  \
# 212     83851  01/09/1998     0        26.9        9.5               3.1
# 213     83851  02/09/1998     0        28.3        9.4               3.8
# 214     83851  03/09/1998     0        31.0        9.4               5.5
# 215     83851  04/09/1998     0        25.8        0.3               4.4
# 216     83851  05/09/1998     0        21.6        1.1               1.0
# 217     83851  06/09/1998     0        24.6        1.8               1.6
# 218     83851  07/09/1998     0        23.6        1.4               1.7
# 219     83851  08/09/1998     0        22.1        0.3               0.8
# 220     83851  09/09/1998     0        21.8        0.9               1.0
# 221     83851  10/09/1998     0        23.1        6.2               2.2
# 222     83851  11/09/1998     0        31.2        8.8               3.6
# 223     83851  12/09/1998     0        33.1        0.0               5.4
# 224     83851  13/09/1998     0        30.8        5.4               4.0
# 225     83851  14/09/1998     0        24.6        3.0               2.9
# 226     83851  15/09/1998     0        24.7        3.9               2.1
# 227     83851  16/09/1998     0        26.5        9.1               2.9
# 228     83851  17/09/1998     0        33.0        8.9               3.9
# 229     83851  18/09/1998     0        31.1        2.9               4.3
# 230     83851  19/09/1998     0        24.0        2.1               2.6
# 231     83851  20/09/1998     0        20.1        0.0               1.7
# 232     83851  21/09/1998     0        22.9        4.6               2.6
# 233     83851  22/09/1998     0        21.9        7.2               3.2
# 234     83851  23/09/1998     0        24.2       10.4               4.2
# 235     83851  24/09/1998     0        29.8       10.0               4.2
# 236     83851  25/09/1998     0        27.9        5.1               3.3
# 237     83851  26/09/1998     0        30.0        8.5               3.3
# 238     83851  27/09/1998     0        30.2        0.7               3.5
# 239     83851  28/09/1998     0        23.3        6.0               0.9
# 240     83851  29/09/1998     0        21.8        0.0               0.5
# 241     83851  30/09/1998     0        22.0        1.4               5.8
# ...       ...         ...   ...         ...        ...               ...
# 6416    83851  01/09/2017     0        25.7        9.4               4.3
# 6417    83851  02/09/2017     0        28.5        9.8               4.5
# 6418    83851  03/09/2017     0        29.5        9.9               3.5
# 6419    83851  04/09/2017     0        29.3        9.9               4.6
# 6420    83851  05/09/2017     0        30.5        9.9               4.9
# 6421    83851  06/09/2017     0        29.3        9.2               5.9
# 6422    83851  07/09/2017     0        31.3        9.7               5.8
# 6423    83851  08/09/2017     0        32.1        9.6               8.4
# 6424    83851  09/09/2017     0        32.6        9.5               8.3
# 6425    83851  10/09/2017     0        31.9        9.8               6.5
# 6426    83851  11/09/2017     0        33.4        9.4               7.3
# 6427    83851  12/09/2017     0        33.6        9.6               7.8
# 6428    83851  13/09/2017     0        33.2        9.8               7.5
# 6429    83851  14/09/2017     0        33.6        9.8               6.7
# 6430    83851  15/09/2017     0        34.4        9.7               9.0
# 6431    83851  16/09/2017     0        33.6        9.6               7.5
# 6432    83851  17/09/2017     0        33.3        9.5               5.9
# 6433    83851  18/09/2017     0        31.9        8.2               5.6
# 6434    83851  19/09/2017     0        31.7        9.6               4.7
# 6435    83851  20/09/2017     0        30.7        9.7               6.3
# 6436    83851  21/09/2017     0        32.4        9.5               5.5
# 6437    83851  22/09/2017     0        32.1        9.7               6.4
# 6438    83851  23/09/2017     0        32.1        8.5               7.3
# 6439    83851  24/09/2017     0        27.3        9.6               7.6
# 6440    83851  25/09/2017     0        28.7        9.4               6.0
# 6441    83851  26/09/2017     0        29.2        8.2               5.5
# 6442    83851  27/09/2017     0        32.8        9.4               5.0
# 6443    83851  28/09/2017     0        31.1        9.7               6.9
# 6444    83851  29/09/2017     0        25.7        0.8               6.2
# 6445    83851  30/09/2017     0        23.1        0.3               3.2
#
#       Temp Comp Media  Umidade Relativa Media Velocidade do Vento Media  \
# 212             18.40                   72.50                       NaN
# 213             19.12                   62.25                       NaN
# 214             20.96                   57.75                       NaN
# 215             21.30                   63.25                       NaN
# 216             18.32                   96.25                       NaN
# 217             19.00                   90.25                       NaN
# 218             19.94                   85.25                       NaN
# 219             18.64                   93.25                       NaN
# 220             17.18                   87.75                       NaN
# 221             17.74                   79.25                       NaN
# 222             22.62                   71.75                       NaN
# 223             24.72                   65.00                       NaN
# 224             23.02                   67.75                       NaN
# 225             20.22                   77.50                       NaN
# 226             19.06                   80.00                       NaN
# 227             19.56                   72.50                       NaN
# 228             23.92                   66.75                       NaN
# 229             23.80                   70.25                       NaN
# 230             19.38                   82.75                       NaN
# 231             18.36                   79.75                       NaN
# 232             17.26                   74.25                       NaN
# 233             16.90                   74.75                       NaN
# 234             17.22                   64.50                       NaN
# 235             19.58                   67.00                       NaN
# 236             20.40                   75.00                       NaN
# 237             20.82                   75.50                       NaN
# 238             21.70                   77.50                       NaN
# 239             20.20                   90.25                       NaN
# 240             19.20                   93.75                       NaN
# 241             18.46                   85.00                       NaN
# ...               ...                     ...                       ...
# 6416            18.94                   74.75                       2.5
# 6417            19.14                   83.00                       0.5
# 6418            19.78                   75.00                       0.5
# 6419            19.98                   66.00                       0.5
# 6420            20.74                   59.00                         0
# 6421            20.66                   73.00                         0
# 6422            22.66                   61.00                       0.5
# 6423            24.06                   47.00                       0.5
# 6424            24.82                   52.00                         1
# 6425            24.10                   53.00                       0.5
# 6426            25.12                   43.00                         1
# 6427            24.50                   53.00                         1
# 6428            24.24                   64.00                       0.5
# 6429            24.44                   51.00                         0
# 6430            25.64                   53.00                       0.5
# 6431            24.32                   60.00                       0.5
# 6432            24.08                   68.00                       0.5
# 6433            22.78                   73.00                         1
# 6434            22.54                   66.00                         1
# 6435            22.20                   67.00                       0.5
# 6436            23.98                   59.00                         1
# 6437            23.42                   74.75                       0.5
# 6438            23.54                   60.00                       1.5
# 6439            21.52                   55.00                         1
# 6440            20.86                   68.00                       1.5
# 6441            21.24                   73.00                       0.5
# 6442            24.18                   57.00                       0.5
# 6443            23.00                   69.00                         1
# 6444            20.42                   84.00                       0.5
# 6445            19.46                   93.00                       0.5
#
#      DataConvertida_00 DataConvertida_12  TempMinima  Precipitacao  mes  \
# 212         1998-09-01        1998-09-01        12.5           0.0    9
# 213         1998-09-02        1998-09-02        11.5           0.0    9
# 214         1998-09-03        1998-09-03        13.0           0.0    9
# 215         1998-09-04        1998-09-04        17.0           0.0    9
# 216         1998-09-05        1998-09-05        17.0           4.6    9
# 217         1998-09-06        1998-09-06        16.0           8.3    9
# 218         1998-09-07        1998-09-07        16.5           4.5    9
# 219         1998-09-08        1998-09-08        17.5          16.2    9
# 220         1998-09-09        1998-09-09        15.5          31.7    9
# 221         1998-09-10        1998-09-10        13.0           0.8    9
# 222         1998-09-11        1998-09-11        15.5           0.0    9
# 223         1998-09-12        1998-09-12        18.5           0.0    9
# 224         1998-09-13        1998-09-13        18.5           0.0    9
# 225         1998-09-14        1998-09-14        17.5           0.0    9
# 226         1998-09-15        1998-09-15        16.0           1.6    9
# 227         1998-09-16        1998-09-16        15.5           1.4    9
# 228         1998-09-17        1998-09-17        17.0           0.0    9
# 229         1998-09-18        1998-09-18        18.5           0.0    9
# 230         1998-09-19        1998-09-19        17.5           3.5    9
# 231         1998-09-20        1998-09-20        17.0           3.1    9
# 232         1998-09-21        1998-09-21        13.8           0.3    9
# 233         1998-09-22        1998-09-22        13.5           0.0    9
# 234         1998-09-23        1998-09-23        13.5           0.0    9
# 235         1998-09-24        1998-09-24        13.5           0.0    9
# 236         1998-09-25        1998-09-25        15.5           0.0    9
# 237         1998-09-26        1998-09-26        14.5           0.0    9
# 238         1998-09-27        1998-09-27        17.5           0.0    9
# 239         1998-09-28        1998-09-28        18.5          19.6    9
# 240         1998-09-29        1998-09-29        18.0           1.0    9
# 241         1998-09-30        1998-09-30        16.5           5.8    9
# ...                ...               ...         ...           ...  ...
# 6416        2017-09-01        2017-09-01        16.2           0.0    9
# 6417        2017-09-02        2017-09-02        15.4           0.0    9
# 6418        2017-09-03        2017-09-03        12.2           0.0    9
# 6419        2017-09-04        2017-09-04        13.2           0.0    9
# 6420        2017-09-05        2017-09-05        12.4           0.0    9
# 6421        2017-09-06        2017-09-06        14.2           0.0    9
# 6422        2017-09-07        2017-09-07        16.0           0.0    9
# 6423        2017-09-08        2017-09-08        16.6           0.0    9
# 6424        2017-09-09        2017-09-09        17.9           0.0    9
# 6425        2017-09-10        2017-09-10        16.6           0.0    9
# 6426        2017-09-11        2017-09-11        16.6           0.0    9
# 6427        2017-09-12        2017-09-12        17.9           0.0    9
# 6428        2017-09-13        2017-09-13        16.8           0.0    9
# 6429        2017-09-14        2017-09-14        16.6           0.0    9
# 6430        2017-09-15        2017-09-15        16.8           0.0    9
# 6431        2017-09-16        2017-09-16        16.2           0.0    9
# 6432        2017-09-17        2017-09-17        17.7           0.0    9
# 6433        2017-09-18        2017-09-18        16.6           0.0    9
# 6434        2017-09-19        2017-09-19        16.0           0.0    9
# 6435        2017-09-20        2017-09-20        15.7           0.0    9
# 6436        2017-09-21        2017-09-21        15.5           0.0    9
# 6437        2017-09-22        2017-09-22        17.2           0.0    9
# 6438        2017-09-23        2017-09-23        17.2           0.0    9
# 6439        2017-09-24        2017-09-24        18.3           0.0    9
# 6440        2017-09-25        2017-09-25        16.2           0.0    9
# 6441        2017-09-26        2017-09-26        14.8           0.0    9
# 6442        2017-09-27        2017-09-27        15.5           0.0    9
# 6443        2017-09-28        2017-09-28        19.3           0.0    9
# 6444        2017-09-29        2017-09-29        17.8           0.0    9
# 6445        2017-09-30        2017-09-30        17.8          15.4    9
#
#                CL  CL 2
# 212     Sem chuva     0
# 213     Sem chuva     0
# 214     Sem chuva     0
# 215     Sem chuva     0
# 216   chovendinho     1
# 217      chovendo     2
# 218   chovendinho     1
# 219        Chuvao     3
# 220    Catastrofe     4
# 221     Sem chuva     0
# 222     Sem chuva     0
# 223     Sem chuva     0
# 224     Sem chuva     0
# 225     Sem chuva     0
# 226     Sem chuva     0
# 227     Sem chuva     0
# 228     Sem chuva     0
# 229     Sem chuva     0
# 230   chovendinho     1
# 231   chovendinho     1
# 232     Sem chuva     0
# 233     Sem chuva     0
# 234     Sem chuva     0
# 235     Sem chuva     0
# 236     Sem chuva     0
# 237     Sem chuva     0
# 238     Sem chuva     0
# 239        Chuvao     3
# 240     Sem chuva     0
# 241      chovendo     2
# ...           ...   ...
# 6416    Sem chuva     0
# 6417    Sem chuva     0
# 6418    Sem chuva     0
# 6419    Sem chuva     0
# 6420    Sem chuva     0
# 6421    Sem chuva     0
# 6422    Sem chuva     0
# 6423    Sem chuva     0
# 6424    Sem chuva     0
# 6425    Sem chuva     0
# 6426    Sem chuva     0
# 6427    Sem chuva     0
# 6428    Sem chuva     0
# 6429    Sem chuva     0
# 6430    Sem chuva     0
# 6431    Sem chuva     0
# 6432    Sem chuva     0
# 6433    Sem chuva     0
# 6434    Sem chuva     0
# 6435    Sem chuva     0
# 6436    Sem chuva     0
# 6437    Sem chuva     0
# 6438    Sem chuva     0
# 6439    Sem chuva     0
# 6440    Sem chuva     0
# 6441    Sem chuva     0
# 6442    Sem chuva     0
# 6443    Sem chuva     0
# 6444    Sem chuva     0
# 6445       Chuvao     3
#
# [532 rows x 16 columns]

# %%
df_j.tail()
# Out:
#       Estacao        Data  Hora  TempMaxima  Insolacao  Evaporacao Piche  \
# 6526    83851  20/12/2017     0        32.4        3.7               3.4
# 6527    83851  21/12/2017     0        22.5        0.0               3.0
# 6528    83851  22/12/2017     0        22.8        0.7               0.9
# 6529    83851  25/12/2017     0        29.5        0.6               3.4
# 6530    83851  26/12/2017     0        31.1        4.7               7.6
#
#       Temp Comp Media  Umidade Relativa Media Velocidade do Vento Media  \
# 6526            24.04                    84.0                         0
# 6527            21.16                    95.0                         0
# 6528            21.06                    95.0                       0.5
# 6529            23.04                    94.0                         1
# 6530            25.20                    77.0                       0.5
#
#      DataConvertida_00 DataConvertida_12  TempMinima  Precipitacao  mes  \
# 6526        2017-12-20        2017-12-20        18.6         104.2   12
# 6527        2017-12-21        2017-12-21        20.3           2.8   12
# 6528        2017-12-22        2017-12-22        20.1          10.6   12
# 6529        2017-12-25        2017-12-25        20.1           0.0   12
# 6530        2017-12-26        2017-12-26        19.9          23.6   12
#
#               CL  CL 2
# 6526  Catastrofe     4
# 6527   Sem chuva     0
# 6528      Chuvao     3
# 6529   Sem chuva     0
# 6530  Catastrofe     4

# %%
df_j[df_j['mes']==2].hist('Precipitacao')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000008F3C780>]], dtype=object)

# %%
df_j[df_j['mes']==2].hist('CL 2',)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000008D2E198>]], dtype=object)

# %%
df_j['Precipitacao'][df_j['DataConvertida_12']=='2006-05']
# Out:
# 2372    0.0
# Name: Precipitacao, dtype: float64

# %% [markdown]
# ### Criando uma lista com valores médios de chuva por mês

# %%
a = df_j['CL 2'][df_j['mes']==12]
mes_01 = sum(a==0)/len(a)*30
mes_01
# Out:
# 20.17241379310345

# %%
sem_chuva= []
chovendinho = []
chovendo = []
chuvao = []
catastrofe = []
for i in range (1,13,1):
    a = df_j['CL 2'][df_j['mes']==i]
    b = sum(a==0)/len(a)*30
    c= sum(a==1)/len(a)*30
    d= sum(a==2)/len(a)*30
    e= sum(a==3)/len(a)*30
    f= sum(a==4)/len(a)*30
    sem_chuva.append(b)
    chovendinho.append(c)
    chovendo.append(d)
    chuvao.append(e)
    catastrofe.append(f)

# %%
print(sem_chuva,chovendinho,chovendo,chuvao,catastrofe)
# Out:
# [17.338403041825092, 21.314168377823407, 23.26530612244898, 26.162790697674417, 26.021505376344084, 26.87150837988827, 26.74033149171271, 27.72972972972973, 25.48872180451128, 23.418367346938776, 22.210526315789473, 20.17241379310345] [1.4258555133079847, 1.4168377823408624, 1.1688311688311688, 0.6976744186046512, 0.7526881720430108, 0.335195530726257, 0.5524861878453039, 0.7027027027027027, 1.0714285714285714, 0.9693877551020409, 1.4736842105263157, 1.293103448275862] [2.737642585551331, 2.402464065708419, 1.2244897959183672, 1.1046511627906979, 0.967741935483871, 0.5027932960893855, 0.6629834254143646, 0.43243243243243246, 1.2406015037593985, 2.193877551020408, 1.736842105263158, 2.793103448275862] [3.7642585551330794, 1.971252566735113, 2.170686456400742, 0.813953488372093, 1.182795698924731, 1.2849162011173185, 1.0497237569060773, 0.6486486486486487, 1.3533834586466165, 1.989795918367347, 2.473684210526316, 2.741379310344828] [4.733840304182509, 2.8952772073921973, 2.170686456400742, 1.2209302325581397, 1.075268817204301, 1.005586592178771, 0.9944751381215469, 0.4864864864864865, 0.8458646616541353, 1.4285714285714284, 2.1052631578947367, 3.0]

# %%
data = [sem_chuva,chovendinho,chovendo,chuvao,catastrofe]

# %%
colunas = ['Janeiro','Fevereiro','Março','Abril','Maio','Junho','Julho','Agosto','Setembro','Outubro','Novembro','Dezembro']

# %%
Chuvas_1998a2017 = pd.DataFrame(data= data, columns=colunas)
Chuvas_1998a2017
# Out:
#      Janeiro  Fevereiro      Março      Abril       Maio      Junho  \
# 0  17.338403  21.314168  23.265306  26.162791  26.021505  26.871508
# 1   1.425856   1.416838   1.168831   0.697674   0.752688   0.335196
# 2   2.737643   2.402464   1.224490   1.104651   0.967742   0.502793
# 3   3.764259   1.971253   2.170686   0.813953   1.182796   1.284916
# 4   4.733840   2.895277   2.170686   1.220930   1.075269   1.005587
#
#        Julho     Agosto   Setembro    Outubro   Novembro   Dezembro
# 0  26.740331  27.729730  25.488722  23.418367  22.210526  20.172414
# 1   0.552486   0.702703   1.071429   0.969388   1.473684   1.293103
# 2   0.662983   0.432432   1.240602   2.193878   1.736842   2.793103
# 3   1.049724   0.648649   1.353383   1.989796   2.473684   2.741379
# 4   0.994475   0.486486   0.845865   1.428571   2.105263   3.000000

# %% [markdown]
# ## Criando Df com periodos menores (7 anos, 5 Anos, 3 Anos) ainda preciso criar um Std dos meses entre os anos de cada classe de chuva

# %%
df_7 = df_j[df_j['DataConvertida_00']>'2009-12-31']
df_7.head()
# Out:
#       Estacao        Data  Hora  TempMaxima  Insolacao  Evaporacao Piche  \
# 3713    83851  01/01/2010     0        26.5        0.9               4.1
# 3714    83851  02/01/2010     0        28.2        0.0               3.2
# 3715    83851  03/01/2010     0        32.5        6.8               1.1
# 3716    83851  04/01/2010     0        32.8        6.8               4.0
# 3717    83851  05/01/2010     0        33.7        6.3               4.4
#
#       Temp Comp Media  Umidade Relativa Media Velocidade do Vento Media  \
# 3713            23.62                   77.00                 1.333.333
# 3714            23.36                   95.75                         0
# 3715            26.22                   73.50                  0.333333
# 3716            26.74                   67.25                         0
# 3717            25.60                   77.75                  0.333333
#
#      DataConvertida_00 DataConvertida_12  TempMinima  Precipitacao  mes  \
# 3713        2010-01-01        2010-01-01        21.4           0.0    1
# 3714        2010-01-02        2010-01-02        21.0          16.8    1
# 3715        2010-01-03        2010-01-03        22.0          10.0    1
# 3716        2010-01-04        2010-01-04        21.9           0.0    1
# 3717        2010-01-05        2010-01-05        21.9           0.0    1
#
#              CL  CL 2
# 3713  Sem chuva     0
# 3714     Chuvao     3
# 3715     Chuvao     3
# 3716  Sem chuva     0
# 3717  Sem chuva     0

# %%
sem_chuva= []
chovendinho = []
chovendo = []
chuvao = []
catastrofe = []
for i in range (1,13,1):
    a = df_7['CL 2'][df_7['mes']==i]
    b = sum(a==0)/len(a)*30
    c= sum(a==1)/len(a)*30
    d= sum(a==2)/len(a)*30
    e= sum(a==3)/len(a)*30
    f= sum(a==4)/len(a)*30
    sem_chuva.append(b)
    chovendinho.append(c)
    chovendo.append(d)
    chuvao.append(e)
    catastrofe.append(f)
data7 = [sem_chuva,chovendinho,chovendo,chuvao,catastrofe]
Chuvas_7anos = pd.DataFrame(data= data7, columns=colunas)
Chuvas_7anos
# Out:
#      Janeiro  Fevereiro      Março      Abril       Maio      Junho  \
# 0  17.611336  22.975610  22.925764  25.833333  26.129032  26.329114
# 1   1.093117   1.170732   1.179039   0.416667   0.604839   0.126582
# 2   3.157895   1.902439   1.572052   1.388889   1.088710   0.253165
# 3   4.372470   1.317073   2.358079   0.833333   0.967742   1.392405
# 4   3.765182   2.634146   1.965066   1.527778   1.209677   1.898734
#
#        Julho     Agosto   Setembro    Outubro  Novembro   Dezembro
# 0  26.781116  27.918367  25.454545  23.588710    22.500  20.836820
# 1   0.515021   0.734694   1.168831   1.209677     0.875   1.506276
# 2   0.901288   0.489796   1.298701   1.451613     1.750   2.259414
# 3   1.158798   0.367347   1.038961   1.935484     2.750   2.635983
# 4   0.643777   0.489796   1.038961   1.814516     2.125   2.761506

# %%
df_5 = df_7[df_7['DataConvertida_00']>'2011-12-31']
df_5.head()
# Out:
#       Estacao        Data  Hora  TempMaxima  Insolacao  Evaporacao Piche  \
# 4443    83851  01/01/2012     0        28.6        1.5               5.7
# 4444    83851  02/01/2012     0        27.6        8.8               3.8
# 4445    83851  03/01/2012     0        31.0       11.9               4.0
# 4446    83851  04/01/2012     0        32.0       11.6               4.4
# 4447    83851  05/01/2012     0        32.0        8.4               4.6
#
#       Temp Comp Media  Umidade Relativa Media Velocidade do Vento Media  \
# 4443            22.68                   82.00                         1
# 4444            21.80                   72.50                         1
# 4445            23.80                   60.50                  0.666667
# 4446            24.50                   56.75                  0.666667
# 4447            23.50                   68.75                  0.666667
#
#      DataConvertida_00 DataConvertida_12  TempMinima  Precipitacao  mes  \
# 4443        2012-01-01        2012-01-01        20.6          14.1    1
# 4444        2012-01-02        2012-01-02        17.2           1.6    1
# 4445        2012-01-03        2012-01-03        15.8           0.0    1
# 4446        2012-01-04        2012-01-04        17.9           0.0    1
# 4447        2012-01-05        2012-01-05        18.5           0.0    1
#
#              CL  CL 2
# 4443     Chuvao     3
# 4444  Sem chuva     0
# 4445  Sem chuva     0
# 4446  Sem chuva     0
# 4447  Sem chuva     0

# %%
sem_chuva= []
chovendinho = []
chovendo = []
chuvao = []
catastrofe = []
for i in range (1,13,1):
    a = df_5['CL 2'][df_5['mes']==i]
    b = sum(a==0)/len(a)*30
    c= sum(a==1)/len(a)*30
    d= sum(a==2)/len(a)*30
    e= sum(a==3)/len(a)*30
    f= sum(a==4)/len(a)*30
    sem_chuva.append(b)
    chovendinho.append(c)
    chovendo.append(d)
    chuvao.append(e)
    catastrofe.append(f)
data5 = [sem_chuva,chovendinho,chovendo,chuvao,catastrofe]
Chuvas_5anos = pd.DataFrame(data= data5, columns=colunas)
Chuvas_5anos
# Out:
#      Janeiro  Fevereiro      Março      Abril       Maio      Junho  \
# 0  19.135135  22.751678  22.634731  26.346154  25.483871  25.762712
# 1   0.810811   1.208054   1.616766   0.576923   0.645161   0.169492
# 2   3.081081   2.013423   1.616766   0.961538   1.451613   0.338983
# 3   3.567568   1.409396   2.335329   0.769231   0.806452   1.355932
# 4   3.405405   2.617450   1.796407   1.346154   1.612903   2.372881
#
#        Julho     Agosto   Setembro    Outubro   Novembro   Dezembro
# 0  26.491228  27.868852  24.912281  24.032258  21.500000  21.186441
# 1   0.526316   0.819672   1.228070   1.129032   1.166667   1.355932
# 2   1.052632   0.491803   1.228070   1.451613   2.000000   2.033898
# 3   1.228070   0.491803   1.228070   1.774194   2.833333   2.711864
# 4   0.701754   0.327869   1.403509   1.612903   2.500000   2.711864

# %%
df_3 = df_5[df_5['DataConvertida_00']>'2014-12-31']
df_3.head()
# Out:
#       Estacao        Data  Hora  TempMaxima  Insolacao  Evaporacao Piche  \
# 5537    83851  01/01/2015     0        33.0        9.3               4.2
# 5538    83851  02/01/2015     0        33.2        6.7               3.8
# 5539    83851  03/01/2015     0        32.8        8.9               5.6
# 5540    83851  04/01/2015     0        27.2        0.2               2.5
# 5541    83851  05/01/2015     0        31.8        5.7               2.6
#
#       Temp Comp Media  Umidade Relativa Media Velocidade do Vento Media  \
# 5537            25.92                    84.0                         1
# 5538            25.88                    85.0                       0.5
# 5539            25.92                    76.0                         1
# 5540            24.56                    83.0                       0.5
# 5541            25.36                    81.0                       0.5
#
#      DataConvertida_00 DataConvertida_12  TempMinima  Precipitacao  mes  \
# 5537        2015-01-01        2015-01-01        22.4           0.0    1
# 5538        2015-01-02        2015-01-02        21.4           6.9    1
# 5539        2015-01-03        2015-01-03        22.0           1.3    1
# 5540        2015-01-04        2015-01-04        22.8           0.0    1
# 5541        2015-01-05        2015-01-05        21.2           0.2    1
#
#              CL  CL 2
# 5537  Sem chuva     0
# 5538   chovendo     2
# 5539  Sem chuva     0
# 5540  Sem chuva     0
# 5541  Sem chuva     0

# %%
sem_chuva= []
chovendinho = []
chovendo = []
chuvao = []
catastrofe = []
for i in range (1,13,1):
    a = df_3['CL 2'][df_3['mes']==i]
    b = sum(a==0)/len(a)*30
    c= sum(a==1)/len(a)*30
    d= sum(a==2)/len(a)*30
    e= sum(a==3)/len(a)*30
    f= sum(a==4)/len(a)*30
    sem_chuva.append(b)
    chovendinho.append(c)
    chovendo.append(d)
    chuvao.append(e)
    catastrofe.append(f)
data3 = [sem_chuva,chovendinho,chovendo,chuvao,catastrofe]
Chuvas_3anos = pd.DataFrame(data= data3, columns=colunas)
Chuvas_3anos
# Out:
#      Janeiro  Fevereiro      Março      Abril       Maio      Junho  \
# 0  19.239130   21.09375  22.702703  27.272727  24.516129  26.551724
# 1   0.652174    1.40625   1.216216   0.454545   0.967742   0.000000
# 2   3.260870    2.34375   1.216216   0.909091   0.967742   0.344828
# 3   3.260870    1.87500   2.027027   0.454545   0.645161   0.689655
# 4   3.586957    3.28125   2.837838   0.909091   2.903226   2.413793
#
#        Julho     Agosto   Setembro    Outubro   Novembro   Dezembro
# 0  26.538462  26.666667  25.925926  21.935484  20.333333  21.976744
# 1   0.769231   1.333333   0.370370   1.935484   2.000000   0.697674
# 2   1.153846   0.666667   0.740741   1.935484   2.000000   2.790698
# 3   0.384615   0.666667   0.740741   2.258065   3.000000   2.790698
# 4   1.153846   0.666667   2.222222   1.935484   2.666667   1.744186

# %%
import xlsxwriter

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('data/Chuvas.xlsx', engine='xlsxwriter')

Chuvas_3anos.to_excel(writer,'Sheet1')
Chuvas_5anos.to_excel(writer,'Sheet2')
Chuvas_7anos.to_excel(writer,'Sheet3')
Chuvas_1998a2017.to_excel(writer,'Sheet4')
writer.save()
