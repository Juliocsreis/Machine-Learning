# %% [markdown]
# # Constructo Wheater

# %% [markdown]
# ### A ideia é fazer tirar uma média por mês de dias que chovem suficientemente para atraphalhar o andamento da obra, para então prever isso no cronograma.

# %% [markdown]
# ### Dados do INMET estação metereológica de Sorocaba-SP - Série Histórica, diária de 01/01/2000 - 17/11/2018

# %% [markdown]
# Acho que talvez seja interessante criar as classes: Chovendinho (atrapalha alguns serviços), chovendo (atrapalha alvenaria), chovendão ( obra alagada), Calamidade de chuva, OMG

# %%
#imports
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('data/raw 2 c.csv', sep=';')

# %%
df.head()
# Out:
#    Estacao        Data  Hora  Precipitacao  TempMaxima  TempMinima  Insolacao  \
# 0    83851  01/02/1998     0           NaN        33.5         NaN        6.1
# 1    83851  01/02/1998  1200           0.0         NaN        23.5        NaN
# 2    83851  02/02/1998     0           NaN        34.1         NaN        7.6
# 3    83851  02/02/1998  1200           0.7         NaN        22.0        NaN
# 4    83851  03/02/1998     0           NaN        33.5         NaN        6.2
#
#    Evaporacao Piche  Temp Comp Media  Umidade Relativa Media  \
# 0               3.0            26.84                   84.50
# 1               NaN              NaN                     NaN
# 2               3.9            27.10                   73.25
# 3               NaN              NaN                     NaN
# 4               3.4            25.66                   70.75
#
#   Velocidade do Vento Media
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
df.describe()
# Out:
#        Estacao          Hora  Precipitacao   TempMaxima   TempMinima  \
# count  13097.0  13097.000000   6559.000000  6516.000000  6499.000000
# mean   83851.0    601.603421      3.686416    27.778622    16.687475
# std        0.0    600.020765     10.510229     4.017201     3.517677
# min    83851.0      0.000000      0.000000    10.700000     3.200000
# 25%    83851.0      0.000000      0.000000    25.200000    14.200000
# 50%    83851.0   1200.000000      0.000000    28.100000    17.000000
# 75%    83851.0   1200.000000      1.000000    30.800000    19.700000
# max    83851.0   1200.000000    164.400000    37.800000    25.100000
#
#          Insolacao  Evaporacao Piche  Temp Comp Media  Umidade Relativa Media
# count  6516.000000       6440.000000      6504.000000             6503.000000
# mean      6.053161          3.507733        21.204299               74.689374
# std       3.380624          1.624978         3.359422                9.683246
# min       0.000000          0.000000         9.100000               38.750000
# 25%       3.275000          2.400000        18.840000               69.000000
# 50%       7.000000          3.400000        21.490000               74.750000
# 75%       8.800000          4.400000        23.780000               81.000000
# max      12.400000         13.900000        29.740000               99.000000

# %%
df.tail()
# Out:
#        Estacao        Data  Hora  Precipitacao  TempMaxima  TempMinima  \
# 13092    83851  22/12/2017  1200          10.6         NaN        20.1
# 13093    83851  25/12/2017     0           NaN        29.5         NaN
# 13094    83851  25/12/2017  1200           0.0         NaN        20.1
# 13095    83851  26/12/2017     0           NaN        31.1         NaN
# 13096    83851  26/12/2017  1200          23.6         NaN        19.9
#
#        Insolacao  Evaporacao Piche  Temp Comp Media  Umidade Relativa Media  \
# 13092        NaN               NaN              NaN                     NaN
# 13093        0.6               NaN            23.04                    94.0
# 13094        NaN               NaN              NaN                     NaN
# 13095        4.7               7.6            25.20                    77.0
# 13096        NaN               NaN              NaN                     NaN
#
#       Velocidade do Vento Media
# 13092                       NaN
# 13093                         1
# 13094                       NaN
# 13095                       0.5
# 13096                       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13097 entries, 0 to 13096
# Data columns (total 11 columns):
# Estacao                      13097 non-null int64
# Data                         13097 non-null object
# Hora                         13097 non-null int64
# Precipitacao                 6559 non-null float64
# TempMaxima                   6516 non-null float64
# TempMinima                   6499 non-null float64
# Insolacao                    6516 non-null float64
# Evaporacao Piche             6440 non-null float64
# Temp Comp Media              6504 non-null float64
# Umidade Relativa Media       6503 non-null float64
# Velocidade do Vento Media    5830 non-null object
# dtypes: float64(7), int64(2), object(2)
# memory usage: 1.1+ MB

# %%
df['DataConvertida'] = pd.to_datetime(df['Data'], format='%d/%m/%Y')

# %%
df.head()
# Out:
#    Estacao        Data  Hora  Precipitacao  TempMaxima  TempMinima  Insolacao  \
# 0    83851  01/02/1998     0           NaN        33.5         NaN        6.1
# 1    83851  01/02/1998  1200           0.0         NaN        23.5        NaN
# 2    83851  02/02/1998     0           NaN        34.1         NaN        7.6
# 3    83851  02/02/1998  1200           0.7         NaN        22.0        NaN
# 4    83851  03/02/1998     0           NaN        33.5         NaN        6.2
#
#    Evaporacao Piche  Temp Comp Media  Umidade Relativa Media  \
# 0               3.0            26.84                   84.50
# 1               NaN              NaN                     NaN
# 2               3.9            27.10                   73.25
# 3               NaN              NaN                     NaN
# 4               3.4            25.66                   70.75
#
#   Velocidade do Vento Media DataConvertida
# 0                       NaN     1998-02-01
# 1                       NaN     1998-02-01
# 2                       NaN     1998-02-02
# 3                       NaN     1998-02-02
# 4                       NaN     1998-02-03

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13097 entries, 0 to 13096
# Data columns (total 12 columns):
# Estacao                      13097 non-null int64
# Data                         13097 non-null object
# Hora                         13097 non-null int64
# Precipitacao                 6559 non-null float64
# TempMaxima                   6516 non-null float64
# TempMinima                   6499 non-null float64
# Insolacao                    6516 non-null float64
# Evaporacao Piche             6440 non-null float64
# Temp Comp Media              6504 non-null float64
# Umidade Relativa Media       6503 non-null float64
# Velocidade do Vento Media    5830 non-null object
# DataConvertida               13097 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int64(2), object(2)
# memory usage: 1.2+ MB

# %%
#--Corrigindo TempMinima e Precipitacao
#Splita rows por hora em 2 dataframes
dfTemp12 = df[df.Hora == 1200]
dfTemp00 = df[df.Hora == 0]

#Imprime dimensoes de ambos subsets e do dataset completo
print("dfTemp00.shape: "+str(dfTemp00.shape)+
      "\ndfTemp12.shape: "+str(dfTemp12.shape)+
      "\ndf.shape: "+str(df.shape)
     )
# Out:
# dfTemp00.shape: (6531, 12)
# dfTemp12.shape: (6566, 12)
# df.shape: (13097, 12)

# %%
#Define chaves para join
dfTemp00['chave'] = dfTemp00["Estacao"].map(str) + dfTemp00["Data"].map(str)
dfTemp12['chave'] = dfTemp12["Estacao"].map(str) + dfTemp12["Data"].map(str)

#Evidencia variaveis TemMinima e Precipitacao deletando demais colunas
dfTemp12.drop(dfTemp12.columns[[0,1,2,4,6,7,8,9,10]], axis=1, inplace=True)
dfTemp12.head()
# Out:
# D:\anaconda\envs\tera-jul2018\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\anaconda\envs\tera-jul2018\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\anaconda\envs\tera-jul2018\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Precipitacao  TempMinima DataConvertida            chave
# 1           0.0        23.5     1998-02-01  8385101/02/1998
# 3           0.7        22.0     1998-02-02  8385102/02/1998
# 5           0.0        22.0     1998-02-03  8385103/02/1998
# 7           0.0        20.5     1998-02-04  8385104/02/1998
# 9           0.0        21.0     1998-02-05  8385105/02/1998

# %%
#Faz o join
df_j = dfTemp00.set_index('chave').join(dfTemp12.set_index('chave'), lsuffix='_00', rsuffix='_12')
# dfEstCamposJoined["TempMinima_00"].mean()
df_j["TempMinima_12"].mean()
# Out:
# 16.687474996153252

# %%
df_j.head()
# Out:
#                  Estacao        Data  Hora  Precipitacao_00  TempMaxima  \
# chave
# 8385101/02/1998    83851  01/02/1998     0              NaN        33.5
# 8385102/02/1998    83851  02/02/1998     0              NaN        34.1
# 8385103/02/1998    83851  03/02/1998     0              NaN        33.5
# 8385104/02/1998    83851  04/02/1998     0              NaN        34.1
# 8385105/02/1998    83851  05/02/1998     0              NaN        34.5
#
#                  TempMinima_00  Insolacao  Evaporacao Piche  Temp Comp Media  \
# chave
# 8385101/02/1998            NaN        6.1               3.0            26.84
# 8385102/02/1998            NaN        7.6               3.9            27.10
# 8385103/02/1998            NaN        6.2               3.4            25.66
# 8385104/02/1998            NaN        6.1               3.9            26.16
# 8385105/02/1998            NaN        8.6               3.7            25.62
#
#                  Umidade Relativa Media Velocidade do Vento Media  \
# chave
# 8385101/02/1998                   84.50                       NaN
# 8385102/02/1998                   73.25                       NaN
# 8385103/02/1998                   70.75                       NaN
# 8385104/02/1998                   70.25                       NaN
# 8385105/02/1998                   76.75                       NaN
#
#                 DataConvertida_00  Precipitacao_12  TempMinima_12  \
# chave
# 8385101/02/1998        1998-02-01              0.0           23.5
# 8385102/02/1998        1998-02-02              0.7           22.0
# 8385103/02/1998        1998-02-03              0.0           22.0
# 8385104/02/1998        1998-02-04              0.0           20.5
# 8385105/02/1998        1998-02-05              0.0           21.0
#
#                 DataConvertida_12
# chave
# 8385101/02/1998        1998-02-01
# 8385102/02/1998        1998-02-02
# 8385103/02/1998        1998-02-03
# 8385104/02/1998        1998-02-04
# 8385105/02/1998        1998-02-05

# %%
#Cria novas variaveis TempMinima e Precipitacao
df_j["TempMinima"] = df_j["TempMinima_12"]
df_j["Precipitacao"] = df_j["Precipitacao_12"]

#Remove colunas temporarias para o join
df_j.drop('TempMinima_00', axis=1, inplace=True)
df_j.drop('TempMinima_12', axis=1, inplace=True)
df_j.drop('Precipitacao_00', axis=1, inplace=True)
df_j.drop('Precipitacao_12', axis=1, inplace=True)

#Reseta o index
df_j = df_j.reset_index(drop=True)

#Renomeia dataframe corrigido
df_j = df_j
df_j.head()
# dfEstCamposCorrigido.tail()
# Out:
#    Estacao        Data  Hora  TempMaxima  Insolacao  Evaporacao Piche  \
# 0    83851  01/02/1998     0        33.5        6.1               3.0
# 1    83851  02/02/1998     0        34.1        7.6               3.9
# 2    83851  03/02/1998     0        33.5        6.2               3.4
# 3    83851  04/02/1998     0        34.1        6.1               3.9
# 4    83851  05/02/1998     0        34.5        8.6               3.7
#
#    Temp Comp Media  Umidade Relativa Media Velocidade do Vento Media  \
# 0            26.84                   84.50                       NaN
# 1            27.10                   73.25                       NaN
# 2            25.66                   70.75                       NaN
# 3            26.16                   70.25                       NaN
# 4            25.62                   76.75                       NaN
#
#   DataConvertida_00 DataConvertida_12  TempMinima  Precipitacao
# 0        1998-02-01        1998-02-01        23.5           0.0
# 1        1998-02-02        1998-02-02        22.0           0.7
# 2        1998-02-03        1998-02-03        22.0           0.0
# 3        1998-02-04        1998-02-04        20.5           0.0
# 4        1998-02-05        1998-02-05        21.0           0.0

# %%
df_j.isnull().sum()
# Out:
# Estacao                        0
# Data                           0
# Hora                           0
# TempMaxima                    15
# Insolacao                     15
# Evaporacao Piche              91
# Temp Comp Media               27
# Umidade Relativa Media        28
# Velocidade do Vento Media    701
# DataConvertida_00              0
# DataConvertida_12              1
# TempMinima                    32
# Precipitacao                   8
# dtype: int64

# %%
df_j.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6531 entries, 0 to 6530
# Data columns (total 13 columns):
# Estacao                      6531 non-null int64
# Data                         6531 non-null object
# Hora                         6531 non-null int64
# TempMaxima                   6516 non-null float64
# Insolacao                    6516 non-null float64
# Evaporacao Piche             6440 non-null float64
# Temp Comp Media              6504 non-null float64
# Umidade Relativa Media       6503 non-null float64
# Velocidade do Vento Media    5830 non-null object
# DataConvertida_00            6531 non-null datetime64[ns]
# DataConvertida_12            6530 non-null datetime64[ns]
# TempMinima                   6499 non-null float64
# Precipitacao                 6523 non-null float64
# dtypes: datetime64[ns](2), float64(7), int64(2), object(2)
# memory usage: 663.4+ KB

# %%
df_j.isnull().sum()/len(df_j)
# Out:
# Estacao                      0.000000
# Data                         0.000000
# Hora                         0.000000
# TempMaxima                   0.002297
# Insolacao                    0.002297
# Evaporacao Piche             0.013934
# Temp Comp Media              0.004134
# Umidade Relativa Media       0.004287
# Velocidade do Vento Media    0.107334
# DataConvertida_00            0.000000
# DataConvertida_12            0.000153
# TempMinima                   0.004900
# Precipitacao                 0.001225
# dtype: float64

# %%
df_j.median()
# Out:
# Estacao                   83851.00
# Hora                          0.00
# TempMaxima                   28.10
# Insolacao                     7.00
# Evaporacao Piche              3.40
# Temp Comp Media              21.49
# Umidade Relativa Media       74.75
# TempMinima                   17.00
# Precipitacao                  0.00
# dtype: float64

# %%
df_j['TempMaxima']=df_j['TempMaxima'].fillna(value=28.10)
df_j['Insolacao']=df_j['Insolacao'].fillna(value=7.0)
df_j['Evaporacao Piche']=df_j['Evaporacao Piche'].fillna(value=3.4)
df_j['Umidade Relativa Media']=df_j['Umidade Relativa Media'].fillna(value=74.75)
df_j['TempMinima']=df_j['TempMinima'].fillna(value=17.00)
df_j['Precipitacao']=df_j['Precipitacao'].fillna(value=0.00)
df_j['Temp Comp Media']=df_j['Temp Comp Media'].fillna(value=21.49)

# %%
df_j.isnull().sum()/len(df_j)
# Out:
# Estacao                      0.000000
# Data                         0.000000
# Hora                         0.000000
# TempMaxima                   0.000000
# Insolacao                    0.000000
# Evaporacao Piche             0.000000
# Temp Comp Media              0.000000
# Umidade Relativa Media       0.000000
# Velocidade do Vento Media    0.107334
# DataConvertida_00            0.000000
# DataConvertida_12            0.000153
# TempMinima                   0.000000
# Precipitacao                 0.000000
# dtype: float64

# %%
df_j['mes'] = pd.DatetimeIndex(df_j['DataConvertida_00']).month

# %%
df_j.head()
# Out:
#    Estacao        Data  Hora  TempMaxima  Insolacao  Evaporacao Piche  \
# 0    83851  01/02/1998     0        33.5        6.1               3.0
# 1    83851  02/02/1998     0        34.1        7.6               3.9
# 2    83851  03/02/1998     0        33.5        6.2               3.4
# 3    83851  04/02/1998     0        34.1        6.1               3.9
# 4    83851  05/02/1998     0        34.5        8.6               3.7
#
#    Temp Comp Media  Umidade Relativa Media Velocidade do Vento Media  \
# 0            26.84                   84.50                       NaN
# 1            27.10                   73.25                       NaN
# 2            25.66                   70.75                       NaN
# 3            26.16                   70.25                       NaN
# 4            25.62                   76.75                       NaN
#
#   DataConvertida_00 DataConvertida_12  TempMinima  Precipitacao  mes
# 0        1998-02-01        1998-02-01        23.5           0.0    2
# 1        1998-02-02        1998-02-02        22.0           0.7    2
# 2        1998-02-03        1998-02-03        22.0           0.0    2
# 3        1998-02-04        1998-02-04        20.5           0.0    2
# 4        1998-02-05        1998-02-05        21.0           0.0    2

# %%
df_j['mes'][:200]
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
# 5      2
# 6      2
# 7      2
# 8      2
# 9      2
# 10     2
# 11     2
# 12     2
# 13     2
# 14     2
# 15     2
# 16     2
# 17     2
# 18     2
# 19     2
# 20     2
# 21     2
# 22     2
# 23     2
# 24     2
# 25     2
# 26     2
# 27     2
# 28     3
# 29     3
#       ..
# 170    7
# 171    7
# 172    7
# 173    7
# 174    7
# 175    7
# 176    7
# 177    7
# 178    7
# 179    7
# 180    7
# 181    8
# 182    8
# 183    8
# 184    8
# 185    8
# 186    8
# 187    8
# 188    8
# 189    8
# 190    8
# 191    8
# 192    8
# 193    8
# 194    8
# 195    8
# 196    8
# 197    8
# 198    8
# 199    8
# Name: mes, Length: 200, dtype: int64

# %%
df_j['Precipitacao'][df_j['mes']==4].median()
# Out:
# 0.0

# %%
df_j['Precipitacao'][1]
# Out:
# 0.69999999999999996

# %%
#Sem chuva 0.0 À 3.00 mm
# Chovendinho 3.00 mm à 5.00 mm
# Chovendo 5.00 à 10 mm
# Chuvão 10 à 20 mm
# Catastrofe 20 <
cl_chuva = []
for i in range (len(df_j)):
    if df_j['Precipitacao'][i] <3:
        chuva = 'Sem chuva'
    elif df_j['Precipitacao'][i] <5:
        chuva = 'chovendinho'
    elif df_j['Precipitacao'][i] <10:
        chuva = 'chovendo'
    elif df_j['Precipitacao'][i] <20:
        chuva = 'Chuvao'
    else:
        chuva = 'Catastrofe'
    cl_chuva.append(chuva)

# %%
#Sem chuva 0.0 À 3.00 mm
# Chovendinho 3.00 mm à 5.00 mm
# Chovendo 5.00 à 10 mm
# Chuvão 10 à 20 mm
# Catastrofe 20 <
cl_chuva2 = []
for i in range (len(df_j)):
    if df_j['Precipitacao'][i] <3:
        chuva2 = 0
    elif df_j['Precipitacao'][i] <5:
        chuva2 = 1
    elif df_j['Precipitacao'][i] <10:
        chuva2 = 2
    elif df_j['Precipitacao'][i] <20:
        chuva2 = 3
    else:
        chuva2 = 4
    cl_chuva2.append(chuva2)

# %%
df_j['CL']=cl_chuva

# %%
df_j['CL 2']=cl_chuva2

# %%
df_j[:8]
# Out:
#    Estacao        Data  Hora  TempMaxima  Insolacao  Evaporacao Piche  \
# 0    83851  01/02/1998     0        33.5        6.1               3.0
# 1    83851  02/02/1998     0        34.1        7.6               3.9
# 2    83851  03/02/1998     0        33.5        6.2               3.4
# 3    83851  04/02/1998     0        34.1        6.1               3.9
# 4    83851  05/02/1998     0        34.5        8.6               3.7
# 5    83851  06/02/1998     0        32.1        3.5               2.7
# 6    83851  07/02/1998     0        33.3        5.7               3.8
# 7    83851  08/02/1998     0        32.8        0.3               2.6
#
#    Temp Comp Media  Umidade Relativa Media Velocidade do Vento Media  \
# 0            26.84                   84.50                       NaN
# 1            27.10                   73.25                       NaN
# 2            25.66                   70.75                       NaN
# 3            26.16                   70.25                       NaN
# 4            25.62                   76.75                       NaN
# 5            25.72                   79.50                       NaN
# 6            26.60                   75.75                       NaN
# 7            26.20                   81.75                       NaN
#
#   DataConvertida_00 DataConvertida_12  TempMinima  Precipitacao  mes  \
# 0        1998-02-01        1998-02-01        23.5           0.0    2
# 1        1998-02-02        1998-02-02        22.0           0.7    2
# 2        1998-02-03        1998-02-03        22.0           0.0    2
# 3        1998-02-04        1998-02-04        20.5           0.0    2
# 4        1998-02-05        1998-02-05        21.0           0.0    2
# 5        1998-02-06        1998-02-06        21.5           6.8    2
# 6        1998-02-07        1998-02-07        21.5           0.0    2
# 7        1998-02-08        1998-02-08        23.0           0.0    2
#
#           CL  CL 2
# 0  Sem chuva     0
# 1  Sem chuva     0
# 2  Sem chuva     0
# 3  Sem chuva     0
# 4  Sem chuva     0
# 5   chovendo     2
# 6  Sem chuva     0
# 7  Sem chuva     0

# %%
df_j['CL 2'].hist(bins=3, figsize= (10,10))

# %%
df_j[df_j['Precipitacao']>1.0]
# Out:
#       Estacao        Data  Hora  TempMaxima  Insolacao  Evaporacao Piche  \
# 5       83851  06/02/1998     0        32.1        3.5               2.7
# 8       83851  09/02/1998     0        31.5        3.9               2.1
# 10      83851  11/02/1998     0        24.4        0.0               0.8
# 11      83851  12/02/1998     0        22.6        0.0               2.1
# 12      83851  13/02/1998     0        20.7        7.0               1.1
# 13      83851  14/02/1998     0        28.2        2.9               1.2
# 14      83851  15/02/1998     0        28.0        0.0               1.3
# 15      83851  16/02/1998     0        24.5        0.0               0.7
# 16      83851  17/02/1998     0        29.4        8.3               2.9
# 18      83851  19/02/1998     0        33.4        9.4               4.1
# 24      83851  25/02/1998     0        30.0        1.5               1.3
# 25      83851  26/02/1998     0        27.7        0.0               1.2
# 26      83851  27/02/1998     0        29.4        2.2               1.8
# 27      83851  28/02/1998     0        29.5        0.0               1.0
# 28      83851  01/03/1998     0        28.7        1.2               1.4
# 30      83851  03/03/1998     0        30.8        6.1               2.6
# 31      83851  04/03/1998     0        32.8        7.2               2.7
# 32      83851  05/03/1998     0        32.5        3.6               2.3
# 33      83851  06/03/1998     0        33.1        8.8               3.5
# 42      83851  15/03/1998     0        28.4        3.4               0.3
# 46      83851  19/03/1998     0        30.6        7.5               3.1
# 49      83851  22/03/1998     0        29.2        2.5               2.1
# 50      83851  23/03/1998     0        29.9        6.6               2.6
# 52      83851  25/03/1998     0        29.2        6.0               2.2
# 56      83851  29/03/1998     0        31.0        6.6               1.8
# 57      83851  30/03/1998     0        25.8        0.0               1.2
# 66      83851  08/04/1998     0        29.0        5.1               2.4
# 67      83851  09/04/1998     0        26.2        1.0               1.6
# 75      83851  17/04/1998     0        27.7        5.0               2.8
# 83      83851  25/04/1998     0        27.2        2.4               1.7
# ...       ...         ...   ...         ...        ...               ...
# 6405    83851  21/08/2017     0        17.1        2.9               1.5
# 6445    83851  30/09/2017     0        23.1        0.3               3.2
# 6446    83851  01/10/2017     0        27.7        6.3               1.6
# 6448    83851  03/10/2017     0        25.3        3.8               1.6
# 6452    83851  07/10/2017     0        27.9        0.0               6.4
# 6453    83851  08/10/2017     0        27.7        5.5               1.8
# 6454    83851  09/10/2017     0        31.5        8.5               2.1
# 6468    83851  23/10/2017     0        21.7        0.1               0.9
# 6471    83851  26/10/2017     0        24.9        2.9               5.0
# 6472    83851  27/10/2017     0        25.4        0.5               1.3
# 6473    83851  28/10/2017     0        29.3        6.0               1.3
# 6475    83851  30/10/2017     0        22.7        0.0               1.3
# 6476    83851  31/10/2017     0        24.7        3.0               0.8
# 6480    83851  04/11/2017     0        29.9        5.6               4.4
# 6481    83851  05/11/2017     0        22.5        0.0               3.1
# 6485    83851  09/11/2017     0        29.3        4.2               3.1
# 6487    83851  11/11/2017     0        27.1        3.6               3.7
# 6493    83851  17/11/2017     0        30.9        2.4               5.4
# 6494    83851  18/11/2017     0        30.5        7.0               2.8
# 6495    83851  19/11/2017     0        29.3        4.2               2.6
# 6497    83851  21/11/2017     0        31.3        4.3               3.0
# 6498    83851  22/11/2017     0        26.1        2.1               2.7
# 6502    83851  26/11/2017     0        28.3        3.0               5.9
# 6503    83851  27/11/2017     0        27.8        2.3               3.2
# 6504    83851  28/11/2017     0        29.8        7.8               1.7
# 6514    83851  08/12/2017     0        32.1        8.1               2.3
# 6526    83851  20/12/2017     0        32.4        3.7               3.4
# 6527    83851  21/12/2017     0        22.5        0.0               3.0
# 6528    83851  22/12/2017     0        22.8        0.7               0.9
# 6530    83851  26/12/2017     0        31.1        4.7               7.6
#
#       Temp Comp Media  Umidade Relativa Media Velocidade do Vento Media  \
# 5               25.72                   79.50                       NaN
# 8               25.90                   78.25                       NaN
# 10              21.88                   81.75                       NaN
# 11              19.76                   82.50                       NaN
# 12              19.50                   90.25                       NaN
# 13              22.36                   81.25                       NaN
# 14              23.00                   88.25                       NaN
# 15              21.54                   91.25                       NaN
# 16              22.48                   74.75                       NaN
# 18              26.26                   68.00                       NaN
# 24              25.26                   82.00                       NaN
# 25              24.36                   88.00                       NaN
# 26              24.26                   86.00                       NaN
# 27              24.16                   85.75                       NaN
# 28              24.52                   90.75                       NaN
# 30              22.84                   85.00                       NaN
# 31              23.82                   77.00                       NaN
# 32              23.60                   76.25                       NaN
# 33              24.94                   72.25                       NaN
# 42              22.52                   75.75                       NaN
# 46              24.48                   76.50                       NaN
# 49              22.88                   91.25                       NaN
# 50              23.06                   88.75                       NaN
# 52              23.42                   80.25                       NaN
# 56              23.52                   82.50                       NaN
# 57              22.50                   88.50                       NaN
# 66              22.14                   79.00                       NaN
# 67              22.34                   87.00                       NaN
# 75              22.62                   86.25                       NaN
# 83              22.38                   81.25                       NaN
# ...               ...                     ...                       ...
# 6405            14.22                   80.00                         2
# 6445            19.46                   93.00                       0.5
# 6446            21.14                   82.00                         0
# 6448            18.94                   71.00                         0
# 6452            21.08                   87.00                       0.5
# 6453            22.56                   83.00                       0.5
# 6454            25.18                   72.00                         0
# 6468            18.12                   73.00                         2
# 6471            20.84                   86.00                       0.5
# 6472            19.96                   91.00                      1.55
# 6473            23.74                   76.00                         1
# 6475            20.44                   94.00                       0.5
# 6476            19.98                   76.00                         0
# 6480            22.22                   92.00                       0.5
# 6481            20.32                   78.00                       0.5
# 6485            23.24                   79.00                         1
# 6487            21.36                   78.00                       0.5
# 6493            23.26                   80.00                         1
# 6494            23.30                   85.00                       0.5
# 6495            23.38                   77.00                       0.5
# 6497            23.90                   87.00                         0
# 6498            20.68                   84.00                         1
# 6502            24.12                   77.00                       1.5
# 6503            23.34                   89.00                       0.5
# 6504            22.88                   71.00                       1.5
# 6514            24.78                   76.00                   0.51444
# 6526            24.04                   84.00                         0
# 6527            21.16                   95.00                         0
# 6528            21.06                   95.00                       0.5
# 6530            25.20                   77.00                       0.5
#
#      DataConvertida_00 DataConvertida_12  TempMinima  Precipitacao  mes  \
# 5           1998-02-06        1998-02-06        21.5           6.8    2
# 8           1998-02-09        1998-02-09        22.0           3.7    2
# 10          1998-02-11        1998-02-11        20.0          19.8    2
# 11          1998-02-12        1998-02-12        18.0           5.0    2
# 12          1998-02-13        1998-02-13        18.0          17.8    2
# 13          1998-02-14        1998-02-14        19.0           8.1    2
# 14          1998-02-15        1998-02-15        19.2           7.0    2
# 15          1998-02-16        1998-02-16        19.0          20.7    2
# 16          1998-02-17        1998-02-17        19.0          10.5    2
# 18          1998-02-19        1998-02-19        19.5           1.2    2
# 24          1998-02-25        1998-02-25        23.5           9.3    2
# 25          1998-02-26        1998-02-26        21.5          11.2    2
# 26          1998-02-27        1998-02-27        21.5           1.6    2
# 27          1998-02-28        1998-02-28        21.5          34.0    2
# 28          1998-03-01        1998-03-01        21.5          24.4    3
# 30          1998-03-03        1998-03-03        20.0           3.4    3
# 31          1998-03-04        1998-03-04        19.5           3.0    3
# 32          1998-03-05        1998-03-05        18.5          15.8    3
# 33          1998-03-06        1998-03-06        20.0          13.6    3
# 42          1998-03-15        1998-03-15        20.0           6.8    3
# 46          1998-03-19        1998-03-19        20.0          16.9    3
# 49          1998-03-22        1998-03-22        20.0          15.6    3
# 50          1998-03-23        1998-03-23        20.0          17.2    3
# 52          1998-03-25        1998-03-25        20.5          10.9    3
# 56          1998-03-29        1998-03-29        19.0          64.6    3
# 57          1998-03-30        1998-03-30        20.5           2.1    3
# 66          1998-04-08        1998-04-08        16.5           2.2    4
# 67          1998-04-09        1998-04-09        19.5          20.2    4
# 75          1998-04-17        1998-04-17        20.0          17.9    4
# 83          1998-04-25        1998-04-25        18.5           3.3    4
# ...                ...               ...         ...           ...  ...
# 6405        2017-08-21        2017-08-21        13.2          35.8    8
# 6445        2017-09-30        2017-09-30        17.8          15.4    9
# 6446        2017-10-01        2017-10-01        17.2           2.6   10
# 6448        2017-10-03        2017-10-03        14.8           9.4   10
# 6452        2017-10-07        2017-10-07        18.7          18.4   10
# 6453        2017-10-08        2017-10-08        18.3           1.8   10
# 6454        2017-10-09        2017-10-09        17.8           5.4   10
# 6468        2017-10-23        2017-10-23        16.3           4.6   10
# 6471        2017-10-26        2017-10-26        17.5          19.4   10
# 6472        2017-10-27        2017-10-27        17.8           6.2   10
# 6473        2017-10-28        2017-10-28        17.8           4.0   10
# 6475        2017-10-30        2017-10-30        18.3          31.6   10
# 6476        2017-10-31        2017-10-31        17.2           6.7   10
# 6480        2017-11-04        2017-11-04        19.4           5.2   11
# 6481        2017-11-05        2017-11-05        18.3          18.2   11
# 6485        2017-11-09        2017-11-09        18.3           4.6   11
# 6487        2017-11-11        2017-11-11        18.7          10.9   11
# 6493        2017-11-17        2017-11-17        18.8          24.0   11
# 6494        2017-11-18        2017-11-18        18.8           3.8   11
# 6495        2017-11-19        2017-11-19        18.8          12.2   11
# 6497        2017-11-21        2017-11-21        19.8           2.6   11
# 6498        2017-11-22        2017-11-22        18.3          19.6   11
# 6502        2017-11-26        2017-11-26        20.3           6.0   11
# 6503        2017-11-27        2017-11-27        20.3          36.8   11
# 6504        2017-11-28        2017-11-28        20.0          18.6   11
# 6514        2017-12-08        2017-12-08        21.0          14.8   12
# 6526        2017-12-20        2017-12-20        18.6         104.2   12
# 6527        2017-12-21        2017-12-21        20.3           2.8   12
# 6528        2017-12-22        2017-12-22        20.1          10.6   12
# 6530        2017-12-26        2017-12-26        19.9          23.6   12
#
#                CL  CL 2
# 5        chovendo     2
# 8     chovendinho     1
# 10         Chuvao     3
# 11       chovendo     2
# 12         Chuvao     3
# 13       chovendo     2
# 14       chovendo     2
# 15     Catastrofe     4
# 16         Chuvao     3
# 18      Sem chuva     0
# 24       chovendo     2
# 25         Chuvao     3
# 26      Sem chuva     0
# 27     Catastrofe     4
# 28     Catastrofe     4
# 30    chovendinho     1
# 31    chovendinho     1
# 32         Chuvao     3
# 33         Chuvao     3
# 42       chovendo     2
# 46         Chuvao     3
# 49         Chuvao     3
# 50         Chuvao     3
# 52         Chuvao     3
# 56     Catastrofe     4
# 57      Sem chuva     0
# 66      Sem chuva     0
# 67     Catastrofe     4
# 75         Chuvao     3
# 83    chovendinho     1
# ...           ...   ...
# 6405   Catastrofe     4
# 6445       Chuvao     3
# 6446    Sem chuva     0
# 6448     chovendo     2
# 6452       Chuvao     3
# 6453    Sem chuva     0
# 6454     chovendo     2
# 6468  chovendinho     1
# 6471       Chuvao     3
# 6472     chovendo     2
# 6473  chovendinho     1
# 6475   Catastrofe     4
# 6476     chovendo     2
# 6480     chovendo     2
# 6481       Chuvao     3
# 6485  chovendinho     1
# 6487       Chuvao     3
# 6493   Catastrofe     4
# 6494  chovendinho     1
# 6495       Chuvao     3
# 6497    Sem chuva     0
# 6498       Chuvao     3
# 6502     chovendo     2
# 6503   Catastrofe     4
# 6504       Chuvao     3
# 6514       Chuvao     3
# 6526   Catastrofe     4
# 6527    Sem chuva     0
# 6528       Chuvao     3
# 6530   Catastrofe     4
#
# [1619 rows x 16 columns]

# %%
df_j.tail()
# Out:
#       Estacao        Data  Hora  TempMaxima  Insolacao  Evaporacao Piche  \
# 6526    83851  20/12/2017     0        32.4        3.7               3.4
# 6527    83851  21/12/2017     0        22.5        0.0               3.0
# 6528    83851  22/12/2017     0        22.8        0.7               0.9
# 6529    83851  25/12/2017     0        29.5        0.6               3.4
# 6530    83851  26/12/2017     0        31.1        4.7               7.6
#
#       Temp Comp Media  Umidade Relativa Media Velocidade do Vento Media  \
# 6526            24.04                    84.0                         0
# 6527            21.16                    95.0                         0
# 6528            21.06                    95.0                       0.5
# 6529            23.04                    94.0                         1
# 6530            25.20                    77.0                       0.5
#
#      DataConvertida_00 DataConvertida_12  TempMinima  Precipitacao  mes  \
# 6526        2017-12-20        2017-12-20        18.6         104.2   12
# 6527        2017-12-21        2017-12-21        20.3           2.8   12
# 6528        2017-12-22        2017-12-22        20.1          10.6   12
# 6529        2017-12-25        2017-12-25        20.1           0.0   12
# 6530        2017-12-26        2017-12-26        19.9          23.6   12
#
#               CL  CL 2
# 6526  Catastrofe     4
# 6527   Sem chuva     0
# 6528      Chuvao     3
# 6529   Sem chuva     0
# 6530  Catastrofe     4

# %%
df_j[df_j['mes']==2].hist('Precipitacao')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000008A3E860>]], dtype=object)

# %%
df_j[df_j['mes']==2].hist('CL 2',)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000008A65A20>]], dtype=object)

# %%
prep2017_02 = df_j['Precipitacao'][pd.Timestamp('2017-03-02'):pd.Timestamp('2017-03-30')]
prep2017_02 = prep2017_02.reset_index(drop=True)
prep2016_02 = df_j.Precipitacao[pd.Timestamp('2016-03-01'):pd.Timestamp('2016-03-31')]
prep2016_02 = prep2017_02.reset_index(drop=True)
prep2015_02 = df_j.Precipitacao[pd.Timestamp('2015-03-01'):pd.Timestamp('2015-03-31')]
prep2015_02 = prep2017_02.reset_index(drop=True)

dfprep = pd.DataFrame({'2017_02' : prep2017_02, '2016_02' : prep2016_02, '2015_02' : prep2015_02})

dfprep.replace(-100, np.nan, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-aa3a54567128> in <module>()
# ----> 1 prep2017_02 = df_j['Precipitacao'][pd.Timestamp('2017-03-02'):pd.Timestamp('2017-03-30')]
#       2 prep2017_02 = prep2017_02.reset_index(drop=True)
#       3 prep2016_02 = df_j.Precipitacao[pd.Timestamp('2016-03-01'):pd.Timestamp('2016-03-31')]
#       4 prep2016_02 = prep2017_02.reset_index(drop=True)
#       5 prep2015_02 = df_j.Precipitacao[pd.Timestamp('2015-03-01'):pd.Timestamp('2015-03-31')]
#
# D:\anaconda\envs\tera-jul2018\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     662             key = check_bool_indexer(self.index, key)
#     663
# --> 664         return self._get_with(key)
#     665
#     666     def _get_with(self, key):
#
# D:\anaconda\envs\tera-jul2018\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     667         # other: fancy integer or otherwise
#     668         if isinstance(key, slice):
# --> 669             indexer = self.index._convert_slice_indexer(key, kind='getitem')
#     670             return self._get_values(indexer)
#     671         elif isinstance(key, ABCDataFrame):
#
# D:\anaconda\envs\tera-jul2018\lib\site-packages\pandas\core\indexes\base.py in _convert_slice_indexer(self, key, kind)
#    1437             """
#    1438             if self.is_integer() or is_index_slice:
# -> 1439                 return slice(self._validate_indexer('slice', key.start, kind),
#    1440                              self._validate_indexer('slice', key.stop, kind),
#    1441                              self._validate_indexer('slice', key.step, kind))
#
# D:\anaconda\envs\tera-jul2018\lib\site-packages\pandas\core\indexes\base.py in _validate_indexer(self, form, key, kind)
#    3493             pass
#    3494         elif kind in ['iloc', 'getitem']:
# -> 3495             self._invalid_indexer(form, key)
#    3496         return key
#    3497
#
# D:\anaconda\envs\tera-jul2018\lib\site-packages\pandas\core\indexes\base.py in _invalid_indexer(self, form, key)
#    1574                         "indexers [{key}] of {kind}".format(
#    1575                             form=form, klass=type(self), key=key,
# -> 1576                             kind=type(key)))
#    1577
#    1578     def get_duplicates(self):
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.range.RangeIndex'> with these indexers [2017-03-02 00:00:00] of <class 'pandas._libs.tslib.Timestamp'>

# %%
# Out:
#   File "<ipython-input-44-ba77e3e5d2e5>", line 1
#     df_j[df_j['Precipitacao']=2017-03-01]
#                              ^
# SyntaxError: invalid syntax
